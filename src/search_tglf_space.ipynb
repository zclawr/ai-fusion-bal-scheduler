# %%
import numpy as np
from search_space import generate_random_input, save_input, perturb_input, save_perturbed_inputs, to_vector, to_dict, get_perturbable_indices

# %% [markdown]
# ## Defaults

# %%
constant_params = {
    "NS": 3,
    "NKY": 9,
    "USE_BPER": True,
    "USE_BPAR": True,
    "USE_AVE_ION_GRID": False,
    "USE_MHD_RULE": False,
    "ALPHA_ZF": -1,
    "KYGRID_MODEL": 4,
    "SAT_RULE": 3,
    "NBASIS_MAX": 6
}

params_geom_miller = {
    "RMIN_LOC": +6.23672E-01,
    "RMAJ_LOC": +2.93276E+00,
    "DRMAJDX_LOC":-1.22980E-01,
    "ZMAJ_LOC":+1.30578E-02,
    "DZMAJDX_LOC":+5.58585E-02,
    "Q_LOC": +2.11441E+00,
    "Q_PRIME_LOC":+1.55015E+01,
    "KAPPA_LOC":+1.33021E+00,
    "S_KAPPA_LOC":+2.06713E-01,
    "DELTA_LOC":+1.25023E-01,
    "S_DELTA_LOC":+2.60027E-01,
    "ZETA_LOC":-1.21010E-02,
    "S_ZETA_LOC":-2.83981E-02
}

params_geom_advanced = {
    "SHAPE_SIN3":-2.44087E-04,
    "SHAPE_S_SIN3":-4.34266E-04,
    "SHAPE_SIN4":+1.45096E-03,
    "SHAPE_S_SIN4":+5.57960E-03,
    "SHAPE_SIN5":+7.64236E-04,
    "SHAPE_S_SIN5":+2.71142E-03,
    "SHAPE_SIN6":+0.00000E+00,
    "SHAPE_S_SIN6":+0.00000E+00,
    "SHAPE_COS0":+1.96118E-02,
    "SHAPE_S_COS0":+1.83169E-02,
    "SHAPE_COS1":+1.58758E-02,
    "SHAPE_S_COS1":+4.18553E-02,
    "SHAPE_COS2":-4.86543E-03,
    "SHAPE_S_COS2":-1.46595E-02,
    "SHAPE_COS3":-1.47306E-03,
    "SHAPE_S_COS3":-7.37064E-03,
    "SHAPE_COS4":+5.00965E-04,
    "SHAPE_S_COS4":+1.83139E-03,
    "SHAPE_COS5":+1.43468E-04,
    "SHAPE_S_COS5":-4.75720E-04,
    "SHAPE_COS6":+0.00000E+00,
    "SHAPE_S_COS6":+0.00000E+00,
    "SIGN_BT":-1.00000E+00,
    "SIGN_IT":+1.00000E+00
}

params_collision_pressure = {
    "ZEFF":+2.24300E+00,
    "XNUE":+4.88549E-02,
    "DEBYE":+2.58487E-02,
    "BETAE":+3.07534E-03,
    "P_PRIME_LOC":-1.59099E-03
}

params_rot = {
    "VEXB_SHEAR":+1.28652E-02
}

params_species = {
    "ZS_2":1,
    "MASS_2":+1.00000E+00,
    "AS_2":+7.51400E-01,
    "TAUS_2":+6.46347E-01,
    "RLNS_2":+6.63982E-01,
    "RLTS_2":+1.07297E+00,
    "VPAR_SHEAR_2":+1.27916E-01,
    "VPAR_2":+1.77710E-01,
    "ZS_3":6,
    "MASS_3":+6.00000E+00,
    "AS_3":+4.14334E-02,
    "TAUS_3":+6.46347E-01,
    "RLNS_3":+4.61217E-01,
    "RLTS_3":+1.07297E+00,
    "VPAR_SHEAR_3":+1.27916E-01,
    "VPAR_3":+1.77710E-01,
    "ZS_1":-1,
    "MASS_1":+2.72444E-04,
    "AS_1":+1.00000E+00,
    "TAUS_1":+1.00000E+00,
    "RLNS_1":+6.13575E-01,
    "RLTS_1":+2.33690E+00,
    "VPAR_SHEAR_1":+1.27916E-01,
    "VPAR_1":+1.77710E-01
}

# %% [markdown]
# ## Constraints

# %%
constant_params = {
    "NS": 3,
    "NKY": 9,
    "USE_BPER": True,
    "USE_BPAR": True,
    "USE_AVE_ION_GRID": False,
    "USE_MHD_RULE": False,
    "ALPHA_ZF": -1,
    "KYGRID_MODEL": 4,
    "SAT_RULE": 3,
    "NBASIS_MAX": 6
}

params_geom_miller = {
    "RMIN_LOC": [0, 1],
    "RMAJ_LOC": [2, 4],
    "DRMAJDX_LOC": [-1, 1],
    "ZMAJ_LOC":[0,1],
    "DZMAJDX_LOC":[0,1],
    "Q_LOC": [1,3],
    "Q_PRIME_LOC":[15, 17],
    "KAPPA_LOC":[0, 2],
    "S_KAPPA_LOC":[0, 2],
    "DELTA_LOC":[-1, 2],
    "S_DELTA_LOC":[-1,2],
    "ZETA_LOC":[-1, 2],
    "S_ZETA_LOC":[-1, 2]
}

params_geom_advanced = {
    "SHAPE_SIN3":[-1, 1],
    "SHAPE_S_SIN3":[-1, 1],
    "SHAPE_SIN4":[-1, 1],
    "SHAPE_S_SIN4":[-1, 1],
    "SHAPE_SIN5":[-1, 1],
    "SHAPE_S_SIN5":[-1, 1],
    "SHAPE_SIN6":[-1, 1],
    "SHAPE_S_SIN6":[-1, 1],
    "SHAPE_COS0":[-1, 1],
    "SHAPE_S_COS0":[-1, 1],
    "SHAPE_COS1":[-1, 1],
    "SHAPE_S_COS1":[-1, 1],
    "SHAPE_COS2":[-1, 1],
    "SHAPE_S_COS2":[-1, 1],
    "SHAPE_COS3":[-1, 1],
    "SHAPE_S_COS3":[-1, 1],
    "SHAPE_COS4":[-1, 1],
    "SHAPE_S_COS4":[-1, 1],
    "SHAPE_COS5":[-1, 1],
    "SHAPE_S_COS5":[-1, 1],
    "SHAPE_COS6":[-1, 1],
    "SHAPE_S_COS6":[-1, 1],
    "SIGN_BT":-1.00000E+00,
    "SIGN_IT":+1.00000E+00
}

params_collision_pressure = {
    "ZEFF":[1, 3],
    "XNUE":[0, 2],
    "DEBYE":[0, 2],
    "BETAE":[0, 2],
    "P_PRIME_LOC":[-1, 1]
}

params_rot = {
    "VEXB_SHEAR":[0, 1]
}

params_species = {
    "ZS_2":1,
    "MASS_2":+1.00000E+00,
    "AS_2":[0, 1],
    "TAUS_2":[0, 2],
    "RLNS_2":[0, 2],
    "RLTS_2":[0, 3],
    "VPAR_SHEAR_2":[0, 1],
    "VPAR_2":[0, 1],
    "ZS_3":6,
    "MASS_3":+6.00000E+00,
    "AS_3":[0, 1],
    "TAUS_3":[0, 2],
    "RLNS_3":[0, 2],
    "RLTS_3":[0, 3],
    "VPAR_SHEAR_3":[0, 1],
    "VPAR_3":[0, 1],
    "ZS_1":-1,
    "MASS_1":+2.72444E-04,
    "AS_1":[0, 1],
    "TAUS_1":[0, 2],
    "RLNS_1":[0, 2],
    "RLTS_1":[0, 3],
    "VPAR_SHEAR_1":[0, 1],
    "VPAR_1":[0, 1]
}

# %%
input_dict = generate_random_input(constant_params, 
                              params_geom_miller, 
                              params_geom_advanced, 
                              params_collision_pressure, 
                              params_rot, 
                              params_species)

save_input(input_dict, './test_input.tglf')
# Out:
# Successfully saved ./test_input.tglf

# %%
perturbable_idxs = get_perturbable_indices(constant_params, 
                              params_geom_miller, 
                              params_geom_advanced, 
                              params_collision_pressure, 
                              params_rot, 
                              params_species)

in_vec = to_vector(input_dict)
perturbed = perturb_input(in_vec, perturbable_idxs, delta=0.01)
print(perturbed.shape)
save_perturbed_inputs(perturbed, './batch-001', input_dict)
# Out:
# (59, 73, 2)
# Directory './batch-001' created successfully.
# Directory './batch-001/input-000' created successfully.
# Successfully saved ./batch-001/input-000/input.tglf
# Directory './batch-001/input-001' created successfully.
# Successfully saved ./batch-001/input-001/input.tglf
# Directory './batch-001/input-002' created successfully.
# Successfully saved ./batch-001/input-002/input.tglf
# Directory './batch-001/input-003' created successfully.
# Successfully saved ./batch-001/input-003/input.tglf
# Directory './batch-001/input-004' created successfully.
# Successfully saved ./batch-001/input-004/input.tglf
# Directory './batch-001/input-005' created successfully.
# Successfully saved ./batch-001/input-005/input.tglf
# Directory './batch-001/input-006' created successfully.
# Successfully saved ./batch-001/input-006/input.tglf
# Directory './batch-001/input-007' created successfully.
# Successfully saved ./batch-001/input-007/input.tglf
# Directory './batch-001/input-008' created successfully.
# Successfully saved ./batch-001/input-008/input.tglf
# Directory './batch-001/input-009' created successfully.
# Successfully saved ./batch-001/input-009/input.tglf
# Directory './batch-001/input-010' created successfully.
# Successfully saved ./batch-001/input-010/input.tglf
# Directory './batch-001/input-011' created successfully.
# Successfully saved ./batch-001/input-011/input.tglf
# Directory './batch-001/input-012' created successfully.
# Successfully saved ./batch-001/input-012/input.tglf
# Directory './batch-001/input-013' created successfully.
# Successfully saved ./batch-001/input-013/input.tglf
# Directory './batch-001/input-014' created successfully.
# Successfully saved ./batch-001/input-014/input.tglf
# Directory './batch-001/input-015' created successfully.
# Successfully saved ./batch-001/input-015/input.tglf
# Directory './batch-001/input-016' created successfully.
# Successfully saved ./batch-001/input-016/input.tglf
# Directory './batch-001/input-017' created successfully.
# Successfully saved ./batch-001/input-017/input.tglf
# Directory './batch-001/input-018' created successfully.
# Successfully saved ./batch-001/input-018/input.tglf
# Directory './batch-001/input-019' created successfully.
# Successfully saved ./batch-001/input-019/input.tglf
# Directory './batch-001/input-020' created successfully.
# Successfully saved ./batch-001/input-020/input.tglf
# Directory './batch-001/input-021' created successfully.
# Successfully saved ./batch-001/input-021/input.tglf
# Directory './batch-001/input-022' created successfully.
# Successfully saved ./batch-001/input-022/input.tglf
# Directory './batch-001/input-023' created successfully.
# Successfully saved ./batch-001/input-023/input.tglf
# Directory './batch-001/input-024' created successfully.
# Successfully saved ./batch-001/input-024/input.tglf
# Directory './batch-001/input-025' created successfully.
# Successfully saved ./batch-001/input-025/input.tglf
# Directory './batch-001/input-026' created successfully.
# Successfully saved ./batch-001/input-026/input.tglf
# Directory './batch-001/input-027' created successfully.
# Successfully saved ./batch-001/input-027/input.tglf
# Directory './batch-001/input-028' created successfully.
# Successfully saved ./batch-001/input-028/input.tglf
# Directory './batch-001/input-029' created successfully.
# Successfully saved ./batch-001/input-029/input.tglf
# Directory './batch-001/input-030' created successfully.
# Successfully saved ./batch-001/input-030/input.tglf
# Directory './batch-001/input-031' created successfully.
# Successfully saved ./batch-001/input-031/input.tglf
# Directory './batch-001/input-032' created successfully.
# Successfully saved ./batch-001/input-032/input.tglf
# Directory './batch-001/input-033' created successfully.
# Successfully saved ./batch-001/input-033/input.tglf
# Directory './batch-001/input-034' created successfully.
# Successfully saved ./batch-001/input-034/input.tglf
# Directory './batch-001/input-035' created successfully.
# Successfully saved ./batch-001/input-035/input.tglf
# Directory './batch-001/input-036' created successfully.
# Successfully saved ./batch-001/input-036/input.tglf
# Directory './batch-001/input-037' created successfully.
# Successfully saved ./batch-001/input-037/input.tglf
# Directory './batch-001/input-038' created successfully.
# Successfully saved ./batch-001/input-038/input.tglf
# Directory './batch-001/input-039' created successfully.
# Successfully saved ./batch-001/input-039/input.tglf
# Directory './batch-001/input-040' created successfully.
# Successfully saved ./batch-001/input-040/input.tglf
# Directory './batch-001/input-041' created successfully.
# Successfully saved ./batch-001/input-041/input.tglf
# Directory './batch-001/input-042' created successfully.
# Successfully saved ./batch-001/input-042/input.tglf
# Directory './batch-001/input-043' created successfully.
# Successfully saved ./batch-001/input-043/input.tglf
# Directory './batch-001/input-044' created successfully.
# Successfully saved ./batch-001/input-044/input.tglf
# Directory './batch-001/input-045' created successfully.
# Successfully saved ./batch-001/input-045/input.tglf
# Directory './batch-001/input-046' created successfully.
# Successfully saved ./batch-001/input-046/input.tglf
# Directory './batch-001/input-047' created successfully.
# Successfully saved ./batch-001/input-047/input.tglf
# Directory './batch-001/input-048' created successfully.
# Successfully saved ./batch-001/input-048/input.tglf
# Directory './batch-001/input-049' created successfully.
# Successfully saved ./batch-001/input-049/input.tglf
# Directory './batch-001/input-050' created successfully.
# Successfully saved ./batch-001/input-050/input.tglf
# Directory './batch-001/input-051' created successfully.
# Successfully saved ./batch-001/input-051/input.tglf
# Directory './batch-001/input-052' created successfully.
# Successfully saved ./batch-001/input-052/input.tglf
# Directory './batch-001/input-053' created successfully.
# Successfully saved ./batch-001/input-053/input.tglf
# Directory './batch-001/input-054' created successfully.
# Successfully saved ./batch-001/input-054/input.tglf
# Directory './batch-001/input-055' created successfully.
# Successfully saved ./batch-001/input-055/input.tglf
# Directory './batch-001/input-056' created successfully.
# Successfully saved ./batch-001/input-056/input.tglf
# Directory './batch-001/input-057' created successfully.
# Successfully saved ./batch-001/input-057/input.tglf
# Directory './batch-001/input-058' created successfully.
# Successfully saved ./batch-001/input-058/input.tglf
# Directory './batch-001/input-059' created successfully.
# Successfully saved ./batch-001/input-059/input.tglf
# Directory './batch-001/input-060' created successfully.
# Successfully saved ./batch-001/input-060/input.tglf
# Directory './batch-001/input-061' created successfully.
# Successfully saved ./batch-001/input-061/input.tglf
# Directory './batch-001/input-062' created successfully.
# Successfully saved ./batch-001/input-062/input.tglf
# Directory './batch-001/input-063' created successfully.
# Successfully saved ./batch-001/input-063/input.tglf
# Directory './batch-001/input-064' created successfully.
# Successfully saved ./batch-001/input-064/input.tglf
# Directory './batch-001/input-065' created successfully.
# Successfully saved ./batch-001/input-065/input.tglf
# Directory './batch-001/input-066' created successfully.
# Successfully saved ./batch-001/input-066/input.tglf
# Directory './batch-001/input-067' created successfully.
# Successfully saved ./batch-001/input-067/input.tglf
# Directory './batch-001/input-068' created successfully.
# Successfully saved ./batch-001/input-068/input.tglf
# Directory './batch-001/input-069' created successfully.
# Successfully saved ./batch-001/input-069/input.tglf
# Directory './batch-001/input-070' created successfully.
# Successfully saved ./batch-001/input-070/input.tglf
# Directory './batch-001/input-071' created successfully.
# Successfully saved ./batch-001/input-071/input.tglf
# Directory './batch-001/input-072' created successfully.
# Successfully saved ./batch-001/input-072/input.tglf
# Directory './batch-001/input-073' created successfully.
# Successfully saved ./batch-001/input-073/input.tglf
# Directory './batch-001/input-074' created successfully.
# Successfully saved ./batch-001/input-074/input.tglf
# Directory './batch-001/input-075' created successfully.
# Successfully saved ./batch-001/input-075/input.tglf
# Directory './batch-001/input-076' created successfully.
# Successfully saved ./batch-001/input-076/input.tglf
# Directory './batch-001/input-077' created successfully.
# Successfully saved ./batch-001/input-077/input.tglf
# Directory './batch-001/input-078' created successfully.
# Successfully saved ./batch-001/input-078/input.tglf
# Directory './batch-001/input-079' created successfully.
# Successfully saved ./batch-001/input-079/input.tglf
# Directory './batch-001/input-080' created successfully.
# Successfully saved ./batch-001/input-080/input.tglf
# Directory './batch-001/input-081' created successfully.
# Successfully saved ./batch-001/input-081/input.tglf
# Directory './batch-001/input-082' created successfully.
# Successfully saved ./batch-001/input-082/input.tglf
# Directory './batch-001/input-083' created successfully.
# Successfully saved ./batch-001/input-083/input.tglf
# Directory './batch-001/input-084' created successfully.
# Successfully saved ./batch-001/input-084/input.tglf
# Directory './batch-001/input-085' created successfully.
# Successfully saved ./batch-001/input-085/input.tglf
# Directory './batch-001/input-086' created successfully.
# Successfully saved ./batch-001/input-086/input.tglf
# Directory './batch-001/input-087' created successfully.
# Successfully saved ./batch-001/input-087/input.tglf
# Directory './batch-001/input-088' created successfully.
# Successfully saved ./batch-001/input-088/input.tglf
# Directory './batch-001/input-089' created successfully.
# Successfully saved ./batch-001/input-089/input.tglf
# Directory './batch-001/input-090' created successfully.
# Successfully saved ./batch-001/input-090/input.tglf
# Directory './batch-001/input-091' created successfully.
# Successfully saved ./batch-001/input-091/input.tglf
# Directory './batch-001/input-092' created successfully.
# Successfully saved ./batch-001/input-092/input.tglf
# Directory './batch-001/input-093' created successfully.
# Successfully saved ./batch-001/input-093/input.tglf
# Directory './batch-001/input-094' created successfully.
# Successfully saved ./batch-001/input-094/input.tglf
# Directory './batch-001/input-095' created successfully.
# Successfully saved ./batch-001/input-095/input.tglf
# Directory './batch-001/input-096' created successfully.
# Successfully saved ./batch-001/input-096/input.tglf
# Directory './batch-001/input-097' created successfully.
# Successfully saved ./batch-001/input-097/input.tglf
# Directory './batch-001/input-098' created successfully.
# Successfully saved ./batch-001/input-098/input.tglf
# Directory './batch-001/input-099' created successfully.
# Successfully saved ./batch-001/input-099/input.tglf
# Directory './batch-001/input-100' created successfully.
# Successfully saved ./batch-001/input-100/input.tglf
# Directory './batch-001/input-101' created successfully.
# Successfully saved ./batch-001/input-101/input.tglf
# Directory './batch-001/input-102' created successfully.
# Successfully saved ./batch-001/input-102/input.tglf
# Directory './batch-001/input-103' created successfully.
# Successfully saved ./batch-001/input-103/input.tglf
# Directory './batch-001/input-104' created successfully.
# Successfully saved ./batch-001/input-104/input.tglf
# Directory './batch-001/input-105' created successfully.
# Successfully saved ./batch-001/input-105/input.tglf
# Directory './batch-001/input-106' created successfully.
# Successfully saved ./batch-001/input-106/input.tglf
# Directory './batch-001/input-107' created successfully.
# Successfully saved ./batch-001/input-107/input.tglf
# Directory './batch-001/input-108' created successfully.
# Successfully saved ./batch-001/input-108/input.tglf
# Directory './batch-001/input-109' created successfully.
# Successfully saved ./batch-001/input-109/input.tglf
# Directory './batch-001/input-110' created successfully.
# Successfully saved ./batch-001/input-110/input.tglf
# Directory './batch-001/input-111' created successfully.
# Successfully saved ./batch-001/input-111/input.tglf
# Directory './batch-001/input-112' created successfully.
# Successfully saved ./batch-001/input-112/input.tglf
# Directory './batch-001/input-113' created successfully.
# Successfully saved ./batch-001/input-113/input.tglf
# Directory './batch-001/input-114' created successfully.
# Successfully saved ./batch-001/input-114/input.tglf
# Directory './batch-001/input-115' created successfully.
# Successfully saved ./batch-001/input-115/input.tglf
# Directory './batch-001/input-116' created successfully.
# Successfully saved ./batch-001/input-116/input.tglf
# Directory './batch-001/input-117' created successfully.
# Successfully saved ./batch-001/input-117/input.tglf
